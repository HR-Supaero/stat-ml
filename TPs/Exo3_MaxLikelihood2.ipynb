# %% [markdown]
# ## Exercice 3 : maximum de vraisemblance 2
#
# On veut quantifier le lien entre deux variables pour lesquelles une relation lineaire semble exister, mais le bruit qui effecte les observations sur la deuxieme variable n'est clairement pas Gaussien.
#
# Nous allons essayer de trouver la relation entre les variables a l'aide d'un modele de regression lineaire dont les parametres seront optimises en maximisant une vraissemblance plutot qu'en minimisant une erreur au carre.

# %%
import numpy as np
import matplotlib.pyplot as plt


MyData=np.genfromtxt('QuantifiedDataExo1_3.csv')

plt.scatter(MyData[:,0],MyData[:,1])
plt.show()

# %% [markdown]
# ### <span style="color:blue">QUESTION 3.1 :</span>
#
# Essayez de resoudre le probleme a l'aide de l'algorithme de regression lineaire de scikit-learn

# %%
X=MyData[:,0]
Y=MyData[:,1]

import sklearn
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X=X[:, np.newaxis], y=Y)
plt.plot(X, Y, 'o')
plt.plot(X, lr.predict(X[:, np.newaxis]), color='red')

# %% [markdown]
# On peut constater que la pente de la courbe est legerement trop forte. Cette mauvaise estimation est due a trois observations a droite de la figure qui font un effet levier. La regression lineaire minimise l'erreur d'approximation au carre sur les observations d'apprentissage. De maniere sous-jacente cela se base sur l'hypothese que les erreurs d'approximation suivent une loi normale centree (et pas forcement reduite). Hors, les erreurs d'approximation autour d'un modele lineaire sont clairement non symetriques ici. Nous allons alors resoudre le probleme au sens du maximum de vraisemblance.
#
# ### <span style="color:blue">QUESTION 3.2 :</span>
#
# On va modeliser le probleme sous la forme :
#
# $ypred_i = a * x_i +b \,,\, \forall i = 1, \ldots, n$
# et $err_i= ypred_i-y_i$
#
# ou les $x_i$ et $y_i$ sont les donnees d'apprentissage pour les observations $i$ dans $[1, 2, ..., n]$, et $ypred_i$ approche $y_i$. Les deux parametres du modele lineaire que l'on cherche a estimer sont $a$ et $b$. Afin de résoudre le probleme, on va alors repondre aux sous-questions suivantes :
#
# #### <span style="color:blue">QUESTION 3.2.1 :</span>
# Codez une fonction qui calcul les erreurs d'approximations pour toutes les observations de $X$ et $Y$ avec un $a$ et un $b$ specifiques.
#
# #### <span style="color:blue">QUESTION 3.2.2 :</span>
#
# Codez une fonction qui calcule la log-vraisemblance (ou la vraisemblance) de parametres pour lesquel l'erreur d'approximation suit une loi normale centree d'ecart type sigma. On donnera la valeur par defaut sigma=2
#
# #### <span style="color:blue">QUESTION 3.2.3 :</span>
#
# Codez une fonction qui calcule la log-vraisemblance (ou la vraisemblance) de parametres pour lesquel l'erreur d'approximation suit une loi de chi2. On fixera par defaut le nombre de degres de liberte ddl=3 et l'echelle de la loi (scale) a 0.4. On fera très attention au fait que la densite de probabilite d'une valeur negative sera egale a zero avec la loi du chi2.
#
# #### <span style="color:blue">QUESTION 3.2.4 :</span>
#
# Utilisez les fonctions de calcul de la (log-)vraisemblance pour trouver une relation lineaire qui semble raisonable, i.e. pour trouver les parametres a et b les plus vraisemblables. On pourra eventuellement s'aider d'une representation du nuage de points qui represente le 'score' attribue a chaque observation.

# %%
#CODE 2.1
def compute_errors(X,Y,theta):
    """
    returns a vector having the same size as X or Y which represents the errors
    with a 1D linear model of parameters theta=[a,b]
    """
    errors = Y - (theta[0] * X + theta[1])
    return errors

compute_errors(X,Y,[1.2,-0.3])
plt.plot(compute_errors(X,Y,[1.2,-0.3],),'o')

# %%
#CODE 2.2

from scipy.stats import norm


def likelihood_normal(X,Y,theta,sigma=2.):
    """
    returns the likelihood of the 1D linear model with parameters theta=[a,b] and
    the errors following a normal law of std=sigma
    """

    errors=compute_errors(X,Y,theta)
    likelihood = np.prod(norm.pdf(errors, loc=0, scale=sigma))

    return likelihood

def loglikelihood_normal(X,Y,theta,sigma=2.):
    """
    returns the log-likelihood of the 1D linear model with parameters theta=[a,b] and
    the errors following a normal law of std=sigma
    """

    errors=compute_errors(X,Y,theta)
    loglikelihood = np.sum(norm.logpdf(errors, loc=0, scale=sigma))

    return loglikelihood

print("likelihood normal : ", likelihood_normal(X,Y,[1.2,-0.3],sigma=2.,))
print("loglikelihood normal : ", loglikelihood_normal(X,Y,[1.2,-0.3],sigma=2.,))
# Out:
# likelihood normal :  2.989581231773985e-15
# loglikelihood normal :  -33.443643073579764

# %%
#CODE 2.3

from scipy.stats import chi2

def likelihood_chi2(X,Y,theta,dof=3,sc=0.4):
    """
    returns the likelihood of the 1D linear model with parameters theta=[a,b] and
    the errors following a chi2 law of dof degrees of freedom
    """

    errors=compute_errors(X,Y,theta)

    likelihood = np.prod(chi2.pdf(errors**2, df=dof, scale=sc))
    
    return likelihood

def loglikelihood_chi2(X,Y,theta,dof=3,sc=0.4):
    """
    returns the log-likelihood of the 1D linear model with parameters theta=[a,b] and
    the errors following a chi2 law of dof degrees of freedom
    """

    errors=compute_errors(X,Y,theta)

    loglikelihood = np.sum(chi2.logpdf(errors**2, df=dof, scale=sc))

    return loglikelihood

print("likelihood chi2 : ", likelihood_chi2(X,Y,[1.2,-0.6],dof=3,sc=0.4,))
print("loglikelihood chi2 : ", loglikelihood_chi2(X,Y,[1.2,-0.6],dof=3,sc=0.4,))
# Out:
# likelihood chi2 :  9.467986618564709e-13
# loglikelihood chi2 :  -27.68568993060469

# %%
#CODE 2.4

print("likelihood normal : ", likelihood_normal(X,Y,[1.2,-0.3],sigma=2.,))

print("likelihood chi2 : ", likelihood_chi2(X,Y,[1.2,-0.6],dof=3,sc=0.4,))



thetas = [[a, b] for a in np.linspace(0, 2, 100) for b in np.linspace(-1, 1, 100)]
max_likelihood_normal = -np.inf
max_theta_normal = None
max_likelihood_chi2 = -np.inf
max_theta_chi2 = None
max_loglikelihood_normal = -np.inf
max_loglikelihood_chi2 = -np.inf

for theta in thetas:
    l_normal = likelihood_normal(X, Y, theta, sigma=2.)
    l_chi2 = likelihood_chi2(X, Y, theta, dof=3, sc=0.4)
    ll_normal = loglikelihood_normal(X, Y, theta, sigma=2.)
    ll_chi2 = loglikelihood_chi2(X, Y, theta, dof=3, sc=0.4)
    print("theta=", theta)
    print("likelihood normal : ", l_normal)
    print("likelihood chi2 : ", l_chi2)
    print("loglikelihood normal : ", loglikelihood_normal(X, Y, theta, sigma=2.))
    print("loglikelihood chi2 : ", loglikelihood_chi2(X, Y, theta, dof=3, sc=0.4))
    if l_normal > max_likelihood_normal:
        max_likelihood_normal = l_normal
        max_theta_normal = theta
    if l_chi2 > max_likelihood_chi2:
        max_likelihood_chi2 = l_chi2
        max_theta_chi2 = theta
    if ll_normal > max_loglikelihood_normal:
        max_loglikelihood_normal = ll_normal
        max_theta_normal = theta
    if ll_chi2 > max_loglikelihood_chi2:
        max_loglikelihood_chi2 = ll_chi2
        max_theta_chi2 = theta

print("\nMaximum likelihood (normal):", max_likelihood_normal, "for theta =", max_theta_normal)
print("Maximum likelihood (chi2):", max_likelihood_chi2, "for theta =", max_theta_chi2)
print("\nMaximum log-likelihood (normal):", max_loglikelihood_normal, "for theta =", max_theta_normal)
print("Maximum log-likelihood (chi2):", max_loglikelihood_chi2, "for theta =", max_theta_chi2)

# Plot log-likelihood (normal) as a function of b for fixed a=1.2
plt.figure()
plt.plot(np.linspace(-1, 1, 100), [loglikelihood_normal(X, Y, [1.2, x], sigma=2.) for x in np.linspace(-1, 1, 100)])
plt.title("Log-likelihood (normal) vs b (a=1.2)")
plt.xlabel("b")
plt.ylabel("log-likelihood (normal)")
plt.grid()

# Plot log-likelihood (chi2) as a function of b for fixed a=1.2
plt.figure()
plt.plot(np.linspace(-1, 1, 100), [loglikelihood_chi2(X, Y, [1.2, x], dof=3, sc=0.4) for x in np.linspace(-1, 1, 100)])
plt.title("Log-likelihood (chi2) vs b (a=1.2)")
plt.xlabel("b")
plt.ylabel("log-likelihood (chi2)")
plt.grid()

# Plot log-likelihood (normal) as a function of a for fixed b=0
plt.figure()
plt.plot(np.linspace(0, 2, 100), [loglikelihood_normal(X, Y, [x, 0], sigma=2.) for x in np.linspace(0, 2, 100)])
plt.title("Log-likelihood (normal) vs a (b=0)")
plt.xlabel("a")
plt.ylabel("log-likelihood (normal)")
plt.grid()

# Plot log-likelihood (chi2) as a function of a for fixed b=0
plt.figure()
plt.plot(np.linspace(0, 2, 100), [loglikelihood_chi2(X, Y, [x, 0], dof=3, sc=0.4) for x in np.linspace(0, 2, 100)])
plt.title("Log-likelihood (chi2) vs a (b=0)")
plt.xlabel("a")
plt.ylabel("log-likelihood (chi2)")
plt.grid()

plt.show()
# Out:
# likelihood normal :  2.989581231773985e-15
# likelihood chi2 :  9.467986618564709e-13
# theta= [np.float64(0.0), np.float64(-1.0)]
# likelihood normal :  4.3867337437771255e-18
# likelihood chi2 :  3.046458671656876e-27
# loglikelihood normal :  -39.96794674564606
# loglikelihood chi2 :  -61.055817686068636
# theta= [np.float64(0.0), np.float64(-0.9797979797979798)]
# likelihood normal :  5.136057041398163e-18
# likelihood chi2 :  1.0823164233575951e-26
# loglikelihood normal :  -39.8102460013756
# loglikelihood chi2 :  -59.78810883714482
# theta= [np.float64(0.0), np.float64(-0.9595959595959596)]
# likelihood normal :  6.0011181409241205e-18
# likelihood chi2 :  3.746631844322396e-26
# loglikelihood normal :  -39.65458586520636
# loglikelihood chi2 :  -58.546355156310945
# theta= [np.float64(0.0), np.float64(-0.9393939393939394)]
# likelihood normal :  6.997586729980797e-18
# likelihood chi2 :  1.2634505000749273e-25
# loglikelihood normal :  -39.50096633713832
# loglikelihood chi2 :  -57.33078085460275
# theta= [np.float64(0.0), np.float64(-0.9191919191919192)]
# likelihood normal :  8.142882694711317e-18
# likelihood chi2 :  4.149559516522787e-25
# loglikelihood normal :  -39.3493874171715
# loglikelihood chi2 :  -56.141625136838755
# theta= [np.float64(0.0), np.float64(-0.898989898989899)]
# likelihood normal :  9.456313073704172e-18
# likelihood chi2 :  1.3269705711719218e-24
# loglikelihood normal :  -39.1998491053059
# loglikelihood chi2 :  -54.97914365371456
# theta= [np.float64(0.0), np.float64(-0.8787878787878788)]
# likelihood normal :  1.0959210807927492e-17
# likelihood chi2 :  4.1306388881181475e-24
# loglikelihood normal :  -39.052351401541515
# loglikelihood chi2 :  -53.84361014238851
# theta= [np.float64(0.0), np.float64(-0.8585858585858586)]
# likelihood normal :  1.2675073750174108e-17
# likelihood chi2 :  1.2512447453733403e-23
# loglikelihood normal :  -38.906894305878325
# loglikelihood chi2 :  -52.7353182867264
# theta= [np.float64(0.0), np.float64(-0.8383838383838383)]
# likelihood normal :  1.462970214419696e-17
# likelihood chi2 :  3.6872219084142836e-23
# loglikelihood normal :  -38.763477818316375
# loglikelihood chi2 :  -51.654583834708255
# theta= [np.float64(0.0), np.float64(-0.8181818181818181)]
# likelihood normal :  1.6851332521010277e-17
# likelihood chi2 :  1.0566727195538225e-22
# loglikelihood normal :  -38.62210193885563
# loglikelihood chi2 :  -50.60174701837996
# theta= [np.float64(0.0), np.float64(-0.797979797979798)]
# likelihood normal :  1.9370765691433957e-17
# likelihood chi2 :  2.9437866071941374e-22
# loglikelihood normal :  -38.48276666749609
# loglikelihood chi2 :  -49.577175331598845
# theta= [np.float64(0.0), np.float64(-0.7777777777777778)]
# likelihood normal :  2.2221486244259614e-17
# likelihood chi2 :  7.969368958811059e-22
# loglikelihood normal :  -38.34547200423778
# loglikelihood chi2 :  -48.58126673326415
# theta= [np.float64(0.0), np.float64(-0.7575757575757576)]
# likelihood normal :  2.5439770693529085e-17
# likelihood chi2 :  2.0955867658858954e-21
# loglikelihood normal :  -38.210217949080665
# loglikelihood chi2 :  -47.6144533595339
# theta= [np.float64(0.0), np.float64(-0.7373737373737373)]
# likelihood normal :  2.9064781162147673e-17
# likelihood chi2 :  5.349917306651855e-21
# loglikelihood normal :  -38.07700450202477
# loglikelihood chi2 :  -46.67720584878709
# theta= [np.float64(0.0), np.float64(-0.7171717171717171)]
# likelihood normal :  3.3138641248893055e-17
# likelihood chi2 :  1.3253326050418813e-20
# loglikelihood normal :  -37.945831663070095
# loglikelihood chi2 :  -45.770038409270526
# theta= [np.float64(0.0), np.float64(-0.696969696969697)]
# likelihood normal :  3.770649050892343e-17
# likelihood chi2 :  3.1841553778115595e-20
# loglikelihood normal :  -37.81669943221663
# loglikelihood chi2 :  -44.893514793525505
# theta= [np.float64(0.0), np.float64(-0.6767676767676767)]
# likelihood normal :  4.281651379177208e-17
# likelihood chi2 :  7.414566202480842e-20
# loglikelihood normal :  -37.68960780946438
# loglikelihood chi2 :  -44.04825538870219
# theta= [np.float64(0.0), np.float64(-0.6565656565656566)]
# likelihood normal :  4.851994153361116e-17
# likelihood chi2 :  1.6722517559165179e-19
# loglikelihood normal :  -37.56455679481335
# loglikelihood chi2 :  -43.23494569183874
# theta= [np.float64(0.0), np.float64(-0.6363636363636364)]
# likelihood normal :  5.487101700064487e-17
# likelihood chi2 :  3.650157242713426e-19
# loglikelihood normal :  -37.44154638826353
# loglikelihood chi2 :  -42.454346520024934
# theta= [np.float64(0.0), np.float64(-0.6161616161616161)]
# likelihood normal :  6.192692643636532e-17
# likelihood chi2 :  7.704544512018193e-19
# loglikelihood normal :  -37.32057658981492
# loglikelihood chi2 :  -41.70730641575861
# theta= [np.float64(0.0), np.float64(-0.5959595959595959)]
# likelihood normal :  6.974768808555228e-17
# likelihood chi2 :  1.5710666965986268e-18
# loglikelihood normal :  -37.201647399467525
# loglikelihood chi2 :  -40.99477686065188
# theta= [np.float64(0.0), np.float64(-0.5757575757575757)]
# likelihood normal :  7.839599616054497e-17
# likelihood chi2 :  3.0916364566416367e-18
# loglikelihood normal :  -37.08475881722135
# loglikelihood chi2 :  -40.31783112555184
# theta= [np.float64(0.0), np.float64(-0.5555555555555556)]
# likelihood normal :  8.793701598821667e-17
# likelihood chi2 :  5.8640692945888e-18
# loglikelihood normal :  -36.969910843076384
# loglikelihood chi2 :  -39.67768789242931
# theta= [np.float64(0.0), np.float64(-0.5353535353535352)]
# likelihood normal :  9.843812683626887e-17
# likelihood chi2 :  1.0705851304245911e-17
# loglikelihood normal :  -36.85710347703263
# loglikelihood chi2 :  -39.075741231029305
# theta= [np.float64(0.0), np.float64(-0.5151515151515151)]
# likelihood normal :  1.0996860927097635e-16
# likelihood chi2 :  1.8782629780267357e-17
# loglikelihood normal :  -36.746336719090095
# loglikelihood chi2 :  -38.51359917901796
# theta= [np.float64(0.0), np.float64(-0.4949494949494949)]
# likelihood normal :  1.2259927435014863e-16
# likelihood chi2 :  3.1607596465939005e-17
# loglikelihood normal :  -36.63761056924877
# loglikelihood chi2 :  -37.993134187698345
# theta= [np.float64(0.0), np.float64(-0.4747474747474747)]
# likelihood normal :  1.364020325081045e-16
# likelihood chi2 :  5.0906030564987e-17
# loglikelihood normal :  -36.530925027508665
# loglikelihood chi2 :  -37.51655027867095
# theta= [np.float64(0.0), np.float64(-0.4545454545454545)]
# likelihood normal :  1.5144940064535294e-16
# likelihood chi2 :  7.826162404591736e-17
# loglikelihood normal :  -36.42628009386978
# loglikelihood chi2 :  -37.086474305397466
# theta= [np.float64(0.0), np.float64(-0.43434343434343425)]
# likelihood normal :  1.6781394669389182e-16
# likelihood chi2 :  1.1448556157716507e-16
# loglikelihood normal :  -36.3236757683321
# loglikelihood chi2 :  -36.70608295861252
# theta= [np.float64(0.0), np.float64(-0.41414141414141414)]
# likelihood normal :  1.855676717867548e-16
# likelihood chi2 :  1.587367488543039e-16
# loglikelihood normal :  -36.22311205089564
# loglikelihood chi2 :  -36.379284511387894
# theta= [np.float64(0.0), np.float64(-0.3939393939393939)]
# likelihood normal :  2.0478133111236798e-16
# likelihood chi2 :  2.0758564773395665e-16
# loglikelihood normal :  -36.12458894156039
# loglikelihood chi2 :  -36.11098765922046
# theta= [np.float64(0.0), np.float64(-0.3737373737373737)]
# likelihood normal :  2.255236955725338e-16
# likelihood chi2 :  2.544275731440267e-16
# loglikelihood normal :  -36.02810644032635
# loglikelihood chi2 :  -35.90751546329998
# theta= [np.float64(0.0), np.float64(-0.3535353535353535)]
# likelihood normal :  2.4786075747682623e-16
# likelihood chi2 :  2.898189869476729e-16
# loglikelihood normal :  -35.93366454719352
# loglikelihood chi2 :  -35.77727512873464
# theta= [np.float64(0.0), np.float64(-0.33333333333333326)]
# likelihood normal :  2.7185488468246527e-16
# likelihood chi2 :  3.032687486076935e-16
# loglikelihood normal :  -35.84126326216192
# loglikelihood chi2 :  -35.731912302397944
# theta= [np.float64(0.0), np.float64(-0.31313131313131304)]
# likelihood normal :  2.975639288112396e-16
# likelihood chi2 :  2.8659176862056727e-16
# loglikelihood normal :  -35.75090258523152
# loglikelihood chi2 :  -35.78847287970475
# theta= [np.float64(0.0), np.float64(-0.2929292929292928)]
# likelihood normal :  3.2504029442494406e-16
# likelihood chi2 :  2.380751109334848e-16
# loglikelihood normal :  -35.66258251640234
# loglikelihood chi2 :  -35.97394545785258
# theta= [np.float64(0.0), np.float64(-0.2727272727272727)]
# likelihood normal :  3.543299772968664e-16
# likelihood chi2 :  1.6566136577665803e-16
# loglikelihood normal :  -35.57630305567437
# loglikelihood chi2 :  -36.33658593430023
# theta= [np.float64(0.0), np.float64(-0.2525252525252525)]
# likelihood normal :  3.854715811555812e-16
# likelihood chi2 :  8.674934407020516e-17
# loglikelihood normal :  -35.492064203047626
# loglikelihood chi2 :  -36.983508816244814
# theta= [np.float64(0.0), np.float64(-0.23232323232323226)]
# likelihood normal :  4.184953234732737e-16
# likelihood chi2 :  2.2888632696964354e-17
# loglikelihood normal :  -35.40986595852209
# loglikelihood chi2 :  -38.31589127535317
# theta= [np.float64(0.0), np.float64(-0.21212121212121204)]
# likelihood normal :  4.534220419971545e-16
# likelihood chi2 :  9.885411329322e-18
# loglikelihood normal :  -35.32970832209776
# loglikelihood chi2 :  -39.155471606671945
# theta= [np.float64(0.0), np.float64(-0.19191919191919182)]
# likelihood normal :  4.902622147513645e-16
# likelihood chi2 :  1.0650142697892593e-17
# loglikelihood normal :  -35.25159129377465
# loglikelihood chi2 :  -39.08095838296399
# theta= [np.float64(0.0), np.float64(-0.1717171717171716)]
# likelihood normal :  5.2901500713971675e-16
# likelihood chi2 :  4.0402228120111266e-18
# loglikelihood normal :  -35.17551487355276
# loglikelihood chi2 :  -40.05023183195265
# theta= [np.float64(0.0), np.float64(-0.1515151515151515)]
# likelihood normal :  5.696673605286442e-16
# likelihood chi2 :  1.0883586100588223e-17
# loglikelihood normal :  -35.10147906143208
# loglikelihood chi2 :  -39.05927588193929
# theta= [np.float64(0.0), np.float64(-0.13131313131313127)]
# likelihood normal :  6.121931372574249e-16
# likelihood chi2 :  2.1621919991088953e-18
# loglikelihood normal :  -35.029483857412615
# loglikelihood chi2 :  -40.67540915237052
# theta= [np.float64(0.0), np.float64(-0.11111111111111105)]
# likelihood normal :  6.565523373835142e-16
# likelihood chi2 :  6.80807376993269e-18
# loglikelihood normal :  -34.95952926149436
# loglikelihood chi2 :  -39.52842244690891
# theta= [np.float64(0.0), np.float64(-0.09090909090909083)]
# likelihood normal :  7.026904026011317e-16
# likelihood chi2 :  8.937250294066946e-17
# loglikelihood normal :  -34.89161527367732
# loglikelihood chi2 :  -36.953718612394326
# theta= [np.float64(0.0), np.float64(-0.07070707070707061)]
# likelihood normal :  7.50537622650768e-16
# likelihood chi2 :  3.116830955237914e-16
# loglikelihood normal :  -34.82574189396149
# loglikelihood chi2 :  -35.70454472175096
# theta= [np.float64(0.0), np.float64(-0.050505050505050386)]
# likelihood normal :  8.000086591492698e-16
# likelihood chi2 :  6.662229982792855e-16
# loglikelihood normal :  -34.761909122346886
# loglikelihood chi2 :  -34.944907227145066
# theta= [np.float64(0.0), np.float64(-0.030303030303030276)]
# likelihood normal :  8.510022011023959e-16
# likelihood chi2 :  1.0240647865732344e-15
# loglikelihood normal :  -34.70011695883349
# loglikelihood chi2 :  -34.51499660215679
# theta= [np.float64(0.0), np.float64(-0.010101010101010055)]
# likelihood normal :  9.034007654068859e-16
# likelihood chi2 :  1.1582690480563684e-15
# loglikelihood normal :  -34.640365403421306
# loglikelihood chi2 :  -34.391849704182945
# theta= [np.float64(0.0), np.float64(0.010101010101010166)]
# likelihood normal :  9.570706544054027e-16
# likelihood chi2 :  8.773730888396492e-16
# loglikelihood normal :  -34.58265445611034
# loglikelihood chi2 :  -34.669599357115416
# theta= [np.float64(0.0), np.float64(0.030303030303030498)]
# likelihood normal :  1.0118620810294598e-15
# likelihood chi2 :  2.268288635310055e-16
# loglikelihood normal :  -34.526984116900586
# loglikelihood chi2 :  -36.02233584589058
# theta= [np.float64(0.0), np.float64(0.05050505050505061)]
# likelihood normal :  1.0676094702629667e-15
# likelihood chi2 :  3.7265041113832473e-16
# loglikelihood normal :  -34.47335438579205
# loglikelihood chi2 :  -35.52589092928296
# theta= [np.float64(0.0), np.float64(0.07070707070707072)]
# likelihood normal :  1.1241319435992763e-15
# likelihood chi2 :  2.0675223751618087e-16
# loglikelihood normal :  -34.421765262784724
# loglikelihood chi2 :  -36.11501051772023
# theta= [np.float64(0.0), np.float64(0.09090909090909105)]
# likelihood normal :  1.1812339908708746e-15
# likelihood chi2 :  1.372946679672682e-15
# loglikelihood normal :  -34.37221674787861
# loglikelihood chi2 :  -34.22181710378595
# theta= [np.float64(0.0), np.float64(0.11111111111111116)]
# likelihood normal :  1.2387063313326433e-15
# likelihood chi2 :  4.457822889940665e-15
# loglikelihood normal :  -34.324708841073715
# loglikelihood chi2 :  -33.04411588932736
# theta= [np.float64(0.0), np.float64(0.1313131313131315)]
# likelihood normal :  1.2963269632125523e-15
# likelihood chi2 :  8.283968766786113e-15
# loglikelihood normal :  -34.27924154237004
# loglikelihood chi2 :  -32.42445422169033
# theta= [np.float64(0.0), np.float64(0.1515151515151516)]
# likelihood normal :  1.3538623981486604e-15
# likelihood chi2 :  1.1430300073532968e-14
# loglikelihood normal :  -34.23581485176757
# loglikelihood chi2 :  -32.10250866429608
# theta= [np.float64(0.0), np.float64(0.1717171717171717)]
# likelihood normal :  1.4110690740543562e-15
# likelihood chi2 :  1.2525795352122296e-14
# loglikelihood normal :  -34.19442876926632
# loglikelihood chi2 :  -32.01098624878843
# theta= [np.float64(0.0), np.float64(0.19191919191919204)]
# likelihood normal :  1.4676949370446063e-15
# likelihood chi2 :  1.1072274889970537e-14
# loglikelihood normal :  -34.15508329486627
# loglikelihood chi2 :  -32.134332168853454
# theta= [np.float64(0.0), np.float64(0.21212121212121215)]
# likelihood normal :  1.5234811801678022e-15
# likelihood chi2 :  7.79417754134449e-15
# loglikelihood normal :  -34.11777842856745
# loglikelihood chi2 :  -32.485399409020296
# theta= [np.float64(0.0), np.float64(0.2323232323232325)]
# likelihood normal :  1.5781641238753607e-15
# likelihood chi2 :  4.190803656774817e-15
# loglikelihood normal :  -34.08251417036983
# loglikelihood chi2 :  -33.10588387584237
# theta= [np.float64(0.0), np.float64(0.2525252525252526)]
# likelihood normal :  1.6314772204806052e-15
# likelihood chi2 :  1.5747582665525963e-15
# loglikelihood normal :  -34.04929052027344
# loglikelihood chi2 :  -34.08467461596649
# theta= [np.float64(0.0), np.float64(0.27272727272727293)]
# likelihood normal :  1.6831531623650848e-15
# likelihood chi2 :  3.392619756984885e-16
# loglikelihood normal :  -34.01810747827825
# loglikelihood chi2 :  -35.61975907528951
# theta= [np.float64(0.0), np.float64(0.29292929292929304)]
# likelihood normal :  1.7329260714380667e-15
# likelihood chi2 :  2.3599683468865824e-17
# loglikelihood normal :  -33.98896504438428
# loglikelihood chi2 :  -38.28529837428739
# theta= [np.float64(0.0), np.float64(0.31313131313131315)]
# likelihood normal :  1.7805337453946327e-15
# likelihood chi2 :  1.43700511587947e-21
# loglikelihood normal :  -33.961863218591525
# loglikelihood chi2 :  -47.99172578567344
# theta= [np.float64(0.0), np.float64(0.3333333333333335)]
# likelihood normal :  1.8257199346959435e-15
# likelihood chi2 :  6.11467311136764e-19
# loglikelihood normal :  -33.93680200089999
# loglikelihood chi2 :  -41.93842545602572
# theta= [np.float64(0.0), np.float64(0.3535353535353536)]
# likelihood normal :  1.8682366229533536e-15
# likelihood chi2 :  2.889921413108603e-17
# loglikelihood normal :  -33.913781391309655
# loglikelihood chi2 :  -38.082717271840146
# theta= [np.float64(0.0), np.float64(0.3737373737373739)]
# likelihood normal :  1.9078462825706235e-15
# likelihood chi2 :  3.032987184705474e-16
# loglikelihood normal :  -33.89280138982055
# loglikelihood chi2 :  -35.7318134844939
# theta= [np.float64(0.0), np.float64(0.39393939393939403)]
# likelihood normal :  1.9443240771127987e-15
# likelihood chi2 :  9.25259696987842e-16
# loglikelihood normal :  -33.87386199643265
# loglikelihood chi2 :  -34.61645722228391
# theta= [np.float64(0.0), np.float64(0.41414141414141437)]
# likelihood normal :  1.9774599819451543e-15
# likelihood chi2 :  1.1437500635082732e-15
# loglikelihood normal :  -33.85696321114596
# loglikelihood chi2 :  -34.40446400177674
# theta= [np.float64(0.0), np.float64(0.4343434343434345)]
# likelihood normal :  2.0070607952307018e-15
# likelihood chi2 :  2.1283417018360307e-16
# loglikelihood normal :  -33.8421050339605
# loglikelihood chi2 :  -36.086018355144915
# theta= [np.float64(0.0), np.float64(0.4545454545454546)]
# likelihood normal :  2.03295201239065e-15
# likelihood chi2 :  2.4110043691023023e-15
# loglikelihood normal :  -33.82928746487624
# loglikelihood chi2 :  -33.6587329835597
# theta= [np.float64(0.0), np.float64(0.4747474747474749)]
# likelihood normal :  2.054979538609257e-15
# likelihood chi2 :  2.0325370314351204e-15
# loglikelihood normal :  -33.818510503893194
# loglikelihood chi2 :  -33.829491612988555
# theta= [np.float64(0.0), np.float64(0.49494949494949503)]
# likelihood normal :  2.0730112158842207e-15
# likelihood chi2 :  1.136762625609336e-15
# loglikelihood normal :  -33.80977415101137
# loglikelihood chi2 :  -34.41059197448946
# theta= [np.float64(0.0), np.float64(0.5151515151515154)]
# likelihood normal :  2.0869381434573126e-15
# likelihood chi2 :  1.6793592389846087e-15
# loglikelihood normal :  -33.80307840623076
# loglikelihood chi2 :  -34.02036407961535
# theta= [np.float64(0.0), np.float64(0.5353535353535355)]
# likelihood normal :  2.096675773170413e-15
# likelihood chi2 :  2.8456180221506193e-15
# loglikelihood normal :  -33.79842326955136
# loglikelihood chi2 :  -33.49299611993923
# theta= [np.float64(0.0), np.float64(0.5555555555555556)]
# likelihood normal :  2.1021647643339e-15
# likelihood chi2 :  1.827497993363325e-13
# loglikelihood normal :  -33.79580874097317
# loglikelihood chi2 :  -29.33065839430421
# theta= [np.float64(0.0), np.float64(0.5757575757575759)]
# likelihood normal :  2.1033715860148283e-15
# likelihood chi2 :  1.1330620045030198e-12
# loglikelihood normal :  -33.795234820496205
# loglikelihood chi2 :  -27.506097409428612
# theta= [np.float64(0.0), np.float64(0.595959595959596)]
# likelihood normal :  2.1002888581924324e-15
# likelihood chi2 :  4.185484359041756e-12
# loglikelihood normal :  -33.79670150812044
# loglikelihood chi2 :  -26.19939868175657
# theta= [np.float64(0.0), np.float64(0.6161616161616164)]
# likelihood normal :  2.0929354269248487e-15
# likelihood chi2 :  1.1391193431479694e-11
# loglikelihood normal :  -33.800208803845905
# loglikelihood chi2 :  -25.198180565075173
# theta= [np.float64(0.0), np.float64(0.6363636363636365)]
# likelihood normal :  2.081356172455961e-15
# likelihood chi2 :  2.4536289475409126e-11
# loglikelihood normal :  -33.80575670767257
# loglikelihood chi2 :  -24.430867891199192
# theta= [np.float64(0.0), np.float64(0.6565656565656568)]
# likelihood normal :  2.0656215529959327e-15
# likelihood chi2 :  4.2489964024020865e-11
# loglikelihood normal :  -33.81334521960046
# loglikelihood chi2 :  -23.881753208495034
# theta= [np.float64(0.0), np.float64(0.6767676767676769)]
# likelihood normal :  2.0458268906636495e-15
# likelihood chi2 :  5.660233064414875e-11
# loglikelihood normal :  -33.82297433962956
# loglikelihood chi2 :  -23.594970954108717
# theta= [np.float64(0.0), np.float64(0.696969696969697)]
# likelihood normal :  2.0220914097153654e-15
# likelihood chi2 :  4.4864357660665377e-11
# loglikelihood normal :  -33.834644067759875
# loglikelihood chi2 :  -23.827377452439933
# theta= [np.float64(0.0), np.float64(0.7171717171717173)]
# likelihood normal :  1.994557040635497e-15
# likelihood chi2 :  3.31207265034538e-11
# loglikelihood normal :  -33.8483544039914
# loglikelihood chi2 :  -24.130861851161313
# theta= [np.float64(0.0), np.float64(0.7373737373737375)]
# likelihood normal :  1.9633870068709535e-15
# likelihood chi2 :  2.372398118887346e-10
# loglikelihood normal :  -33.864105348324145
# loglikelihood chi2 :  -22.161949621873802
# theta= [np.float64(0.0), np.float64(0.7575757575757578)]
# likelihood normal :  1.928764213893242e-15
# likelihood chi2 :  6.40919074084576e-10
# loglikelihood normal :  -33.88189690075809
# loglikelihood chi2 :  -21.168117916456055
# theta= [np.float64(0.0), np.float64(0.7777777777777779)]
# likelihood normal :  1.8908894628234242e-15
# likelihood chi2 :  1.316571459730265e-09
# loglikelihood normal :  -33.901729061293274
# loglikelihood chi2 :  -20.44823485838154
# theta= [np.float64(0.0), np.float64(0.7979797979797982)]
# likelihood normal :  1.8499795130114113e-15
# likelihood chi2 :  2.313935417559144e-09
# loglikelihood normal :  -33.92360182992965
# loglikelihood chi2 :  -19.88431611800297
# theta= [np.float64(0.0), np.float64(0.8181818181818183)]
# likelihood normal :  1.8062650196901632e-15
# likelihood chi2 :  3.6363444150963167e-09
# loglikelihood normal :  -33.94751520666725
# loglikelihood chi2 :  -19.43228694149333
# theta= [np.float64(0.0), np.float64(0.8383838383838385)]
# likelihood normal :  1.7599883741024194e-15
# likelihood chi2 :  5.22250088717189e-09
# loglikelihood normal :  -33.97346919150607
# loglikelihood chi2 :  -19.0702894526229
# theta= [np.float64(0.0), np.float64(0.8585858585858588)]
# likelihood normal :  1.7114014743080251e-15
# likelihood chi2 :  6.9414244506965e-09
# loglikelihood normal :  -34.001463784446095
# loglikelihood chi2 :  -18.78575883122732
# theta= [np.float64(0.0), np.float64(0.8787878787878789)]
# likelihood normal :  1.6607634552187256e-15
# likelihood chi2 :  8.605311546287384e-09
# loglikelihood normal :  -34.03149898548733
# loglikelihood chi2 :  -18.57088620267539
# theta= [np.float64(0.0), np.float64(0.8989898989898992)]
# likelihood normal :  1.6083384062788704e-15
# likelihood chi2 :  9.999762049477696e-09
# loglikelihood normal :  -34.063574794629794
# loglikelihood chi2 :  -18.420704539287705
# theta= [np.float64(0.0), np.float64(0.9191919191919193)]
# likelihood normal :  1.5543931046287031e-15
# likelihood chi2 :  1.0925003252337454e-08
# loglikelihood normal :  -34.09769121187347
# loglikelihood chi2 :  -18.33221179826801
# theta= [np.float64(0.0), np.float64(0.9393939393939394)]
# likelihood normal :  1.499194790574378e-15
# likelihood chi2 :  1.1237592753128397e-08
# loglikelihood normal :  -34.13384823721835
# loglikelihood chi2 :  -18.30400118328922
# theta= [np.float64(0.0), np.float64(0.9595959595959598)]
# likelihood normal :  1.443009010775988e-15
# likelihood chi2 :  1.0881286575408649e-08
# loglikelihood normal :  -34.17204587066444
# loglikelihood chi2 :  -18.336221351093524
# theta= [np.float64(0.0), np.float64(0.9797979797979799)]
# likelihood normal :  1.3860975527896055e-15
# likelihood chi2 :  9.898710743164008e-09
# loglikelihood normal :  -34.212284112211755
# loglikelihood chi2 :  -18.430861316249494
# theta= [np.float64(0.0), np.float64(1.0)]
# likelihood normal :  1.3287164925051093e-15
# likelihood chi2 :  8.421113918108332e-09
# loglikelihood normal :  -34.25456296186028
# loglikelihood chi2 :  -18.592523723130142
# theta= [np.float64(0.020202020202020204), np.float64(-1.0)]
# likelihood normal :  4.787182614796733e-18
# likelihood chi2 :  6.467164932749305e-27
# loglikelihood normal :  -39.880589616143055
# loglikelihood chi2 :  -60.303059684950284
# theta= [np.float64(0.020202020202020204), np.float64(-0.9797979797979798)]
# likelihood normal :  5.5995849128652835e-18
# likelihood chi2 :  2.2717322677774215e-26
# loglikelihood normal :  -39.72383920160157
# loglikelihood chi2 :  -59.04666976381664
# theta= [np.float64(0.020202020202020204), np.float64(-0.9595959595959596)]
# likelihood normal :  6.536502776129007e-18
# likelihood chi2 :  7.775019074998366e-26
# loglikelihood normal :  -39.56912939516128
# loglikelihood chi2 :  -57.8162965064069
# theta= [np.float64(0.020202020202020204), np.float64(-0.9393939393939394)]
# likelihood normal :  7.614630610818779e-18
# likelihood chi2 :  2.592077628974645e-25
# loglikelihood normal :  -39.41646019682222
# loglikelihood chi2 :  -56.61216759735949
# theta= [np.float64(0.020202020202020204), np.float64(-0.9191919191919192)]
# likelihood normal :  8.852501436801065e-18
# likelihood chi2 :  8.415719455992447e-25
# loglikelihood normal :  -39.26583160658436
# loglikelihood chi2 :  -55.43452600401305
# theta= [np.float64(0.020202020202020204), np.float64(-0.898989898989899)]
# likelihood normal :  1.0270626751056331e-17
# likelihood chi2 :  2.6602251721637375e-24
# loglikelihood normal :  -39.11724362444772
# loglikelihood chi2 :  -54.283631461456835
# theta= [np.float64(0.020202020202020204), np.float64(-0.8787878787878788)]
# likelihood normal :  1.1891637517679504e-17
# likelihood chi2 :  8.184810683598359e-24
# loglikelihood normal :  -38.970696250412296
# loglikelihood chi2 :  -53.159762150977926
# theta= [np.float64(0.020202020202020204), np.float64(-0.8585858585858586)]
# likelihood normal :  1.3740424608566981e-17
# likelihood chi2 :  2.450373678769994e-23
# loglikelihood normal :  -38.82618948447808
# loglikelihood chi2 :  -52.06321660398976
# theta= [np.float64(0.020202020202020204), np.float64(-0.8383838383838383)]
# likelihood normal :  1.584427675729818e-17
# likelihood chi2 :  7.135920601847035e-23
# loglikelihood normal :  -38.68372332664507
# loglikelihood chi2 :  -50.994315870070025
# theta= [np.float64(0.020202020202020204), np.float64(-0.8181818181818181)]
# likelihood normal :  1.8233013819205515e-17
# likelihood chi2 :  2.020744585115614e-22
# loglikelihood normal :  -38.5432977769133
# loglikelihood chi2 :  -49.953405995881695
# theta= [np.float64(0.020202020202020204), np.float64(-0.797979797979798)]
# likelihood normal :  2.093911285732469e-17
# likelihood chi2 :  5.562297119412514e-22
# loglikelihood normal :  -38.40491283528272
# loglikelihood chi2 :  -48.9408608719564
# theta= [np.float64(0.020202020202020204), np.float64(-0.7777777777777778)]
# likelihood normal :  2.399782430162026e-17
# likelihood chi2 :  1.4876555667762279e-21
# loglikelihood normal :  -38.268568501753364
# loglikelihood chi2 :  -47.95708551719899
# theta= [np.float64(0.020202020202020204), np.float64(-0.7575757575757576)]
# likelihood normal :  2.74472751631011e-17
# likelihood chi2 :  3.864247880344265e-21
# loglikelihood normal :  -38.134264776325224
# loglikelihood chi2 :  -47.002519887354474
# theta= [np.float64(0.020202020202020204), np.float64(-0.7373737373737373)]
# likelihood normal :  3.13285560313969e-17
# likelihood chi2 :  9.743921339178117e-21
# loglikelihood normal :  -38.00200165899829
# loglikelihood chi2 :  -46.07764331468445
# theta= [np.float64(0.020202020202020204), np.float64(-0.7171717171717171)]
# likelihood normal :  3.568578835092303e-17
# likelihood chi2 :  2.383862679360856e-20
# loglikelihood normal :  -37.87177914977258
# loglikelihood chi2 :  -45.18297971327605
# theta= [np.float64(0.020202020202020204), np.float64(-0.696969696969697)]
# likelihood normal :  4.056616826439089e-17
# likelihood chi2 :  5.6553281715275e-20
# loglikelihood normal :  -37.74359724864808
# loglikelihood chi2 :  -44.31910371989627
# theta= [np.float64(0.020202020202020204), np.float64(-0.6767676767676767)]
# likelihood normal :  4.601998314107358e-17
# likelihood chi2 :  1.3001358769821783e-19
# loglikelihood normal :  -37.61745595562479
# loglikelihood chi2 :  -43.486647987125764
# theta= [np.float64(0.020202020202020204), np.float64(-0.6565656565656566)]
# likelihood normal :  5.2100596779261525e-17
# likelihood chi2 :  2.8944782172086236e-19
# loglikelihood normal :  -37.49335527070272
# loglikelihood chi2 :  -42.686311907958284
# theta= [np.float64(0.020202020202020204), np.float64(-0.6363636363636364)]
# likelihood normal :  5.886439919631329e-17
# likelihood chi2 :  6.235411850358791e-19
# loglikelihood normal :  -37.37129519388186
# loglikelihood chi2 :  -41.918872135347954
# theta= [np.float64(0.020202020202020204), np.float64(-0.6161616161616161)]
# likelihood normal :  6.637071690425652e-17
# likelihood chi2 :  1.2986643308027745e-18
# loglikelihood normal :  -37.25127572516222
# loglikelihood chi2 :  -41.18519537544543
# theta= [np.float64(0.020202020202020204), np.float64(-0.5959595959595959)]
# likelihood normal :  7.468167962253497e-17
# likelihood chi2 :  2.6124215308532193e-18
# loglikelihood normal :  -37.133296864543794
# loglikelihood chi2 :  -40.48625409309003
# theta= [np.float64(0.020202020202020204), np.float64(-0.5757575757575757)]
# likelihood normal :  8.386203951036816e-17
# likelihood chi2 :  5.070227460972825e-18
# loglikelihood normal :  -37.01735861202657
# loglikelihood chi2 :  -39.82314599319889
# theta= [np.float64(0.020202020202020204), np.float64(-0.5555555555555556)]
# likelihood normal :  9.397893921684698e-17
# likelihood chi2 :  9.482170159272388e-18
# loglikelihood normal :  -36.90346096761057
# loglikelihood chi2 :  -39.19711846406955
# theta= [np.float64(0.020202020202020204), np.float64(-0.5353535353535352)]
# likelihood normal :  1.051016253540229e-16
# likelihood chi2 :  1.7063335431834817e-17
# loglikelihood normal :  -36.79160393129579
# loglikelihood chi2 :  -38.60959963910836
# theta= [np.float64(0.020202020202020204), np.float64(-0.5151515151515151)]
# likelihood normal :  1.1730110440243234e-16
# likelihood chi2 :  2.949713792771333e-17
# loglikelihood normal :  -36.68178750308222
# loglikelihood chi2 :  -38.06223843465329
# theta= [np.float64(0.020202020202020204), np.float64(-0.4949494949494949)]
# likelihood normal :  1.3064973856390807e-16
# likelihood chi2 :  4.889008830108502e-17
# loglikelihood normal :  -36.574011682969854
# loglikelihood chi2 :  -37.5569569911864
# theta= [np.float64(0.020202020202020204), np.float64(-0.4747474747474747)]
# likelihood normal :  1.452207796856606e-16
# likelihood chi2 :  7.751806866888946e-17
# loglikelihood normal :  -36.46827647095872
# loglikelihood chi2 :  -37.09602062059269
# theta= [np.float64(0.020202020202020204), np.float64(-0.4545454545454545)]
# likelihood normal :  1.610878400930462e-16
# likelihood chi2 :  1.1726057646719357e-16
# loglikelihood normal :  -36.36458186704878
# loglikelihood chi2 :  -36.68213306622357
# theta= [np.float64(0.020202020202020204), np.float64(-0.43434343434343425)]
# likelihood normal :  1.7832429998456362e-16
# likelihood chi2 :  1.6867305808390494e-16
# loglikelihood normal :  -36.262927871240066
# loglikelihood chi2 :  -36.31856940021332
# theta= [np.float64(0.020202020202020204), np.float64(-0.41414141414141414)]
# likelihood normal :  1.970026519574373e-16
# likelihood chi2 :  2.29789790162124e-16
# loglikelihood normal :  -36.16331448353257
# loglikelihood chi2 :  -36.00936673869875
# theta= [np.float64(0.020202020202020204), np.float64(-0.3939393939393939)]
# likelihood normal :  2.1719378423909166e-16
# likelihood chi2 :  2.949849672355952e-16
# loglikelihood normal :  -36.06574170392628
# loglikelihood chi2 :  -35.75960727737484
# theta= [np.float64(0.020202020202020204), np.float64(-0.3737373737373737)]
# likelihood normal :  2.389662052896054e-16
# likelihood chi2 :  3.5448849810227937e-16
# loglikelihood normal :  -35.9702095324212
# loglikelihood chi2 :  -35.57585577385665
# theta= [np.float64(0.020202020202020204), np.float64(-0.3535353535353535)]
# likelihood normal :  2.623852136008023e-16
# likelihood chi2 :  3.953063340887108e-16
# loglikelihood normal :  -35.87671796901735
# loglikelihood chi2 :  -35.46687068022069
# theta= [np.float64(0.020202020202020204), np.float64(-0.33333333333333326)]
# likelihood normal :  2.8751201773412563e-16
# likelihood chi2 :  4.041131950900058e-16
# loglikelihood normal :  -35.7852670137147
# loglikelihood chi2 :  -35.44483664931005
# theta= [np.float64(0.020202020202020204), np.float64(-0.31313131313131304)]
# likelihood normal :  3.144028128942076e-16
# likelihood chi2 :  3.7198078833364887e-16
# loglikelihood normal :  -35.695856666513265
# loglikelihood chi2 :  -35.52768946521768
# theta= [np.float64(0.020202020202020204), np.float64(-0.2929292929292928)]
# likelihood normal :  3.4310782160788604e-16
# likelihood chi2 :  2.996103130334552e-16
# loglikelihood normal :  -35.608486927413054
# loglikelihood chi2 :  -35.744049000167124
# theta= [np.float64(0.020202020202020204), np.float64(-0.2727272727272727)]
# likelihood normal :  3.736703073466584e-16
# likelihood chi2 :  2.0050384067083376e-16
# loglikelihood normal :  -35.52315779641405
# loglikelihood chi2 :  -36.14569827186416
# theta= [np.float64(0.020202020202020204), np.float64(-0.2525252525252525)]
# likelihood normal :  4.061255711694438e-16
# likelihood chi2 :  9.912701436656184e-17
# loglikelihood normal :  -35.43986927351626
# loglikelihood chi2 :  -36.85012967266573
# theta= [np.float64(0.020202020202020204), np.float64(-0.23232323232323226)]
# likelihood normal :  4.404999426455406e-16
# likelihood chi2 :  2.2570690142705506e-17
# loglikelihood normal :  -35.35862135871968
# loglikelihood chi2 :  -38.32987950565291
# theta= [np.float64(0.020202020202020204), np.float64(-0.21212121212121204)]
# likelihood normal :  4.768097774170052e-16
# likelihood chi2 :  1.2187437784735678e-17
# loglikelihood normal :  -35.27941405202432
# loglikelihood chi2 :  -38.94612594242409
# theta= [np.float64(0.020202020202020204), np.float64(-0.19191919191919182)]
# likelihood normal :  5.150604747468354e-16
# likelihood chi2 :  8.85665797231151e-18
# loglikelihood normal :  -35.202247353430174
# loglikelihood chi2 :  -39.265362184463214
# theta= [np.float64(0.020202020202020204), np.float64(-0.1717171717171716)]
# likelihood normal :  5.552455292455218e-16
# likelihood chi2 :  8.58774214106033e-18
# loglikelihood normal :  -35.12712126293725
# loglikelihood chi2 :  -39.29619581982073
# theta= [np.float64(0.020202020202020204), np.float64(-0.1515151515151515)]
# likelihood normal :  5.973456316456373e-16
# likelihood chi2 :  1.2627629036679935e-17
# loglikelihood normal :  -35.054035780545526
# loglikelihood chi2 :  -38.91064447988134
# theta= [np.float64(0.020202020202020204), np.float64(-0.13131313131313127)]
# likelihood normal :  6.413278339750498e-16
# likelihood chi2 :  2.833241937107162e-20
# loglikelihood normal :  -34.982990906255026
# loglikelihood chi2 :  -45.01028024306462
# theta= [np.float64(0.020202020202020204), np.float64(-0.11111111111111105)]
# likelihood normal :  6.871447947390579e-16
# likelihood chi2 :  1.2399450353327589e-17
# loglikelihood normal :  -34.91398664006573
# loglikelihood chi2 :  -38.928879528608825
# theta= [np.float64(0.020202020202020204), np.float64(-0.09090909090909083)]
# likelihood normal :  7.347341197378207e-16
# likelihood chi2 :  1.2546092538944574e-16
# loglikelihood normal :  -34.84702298197766
# loglikelihood chi2 :  -36.614537315279435
# theta= [np.float64(0.020202020202020204), np.float64(-0.07070707070707061)]
# likelihood normal :  7.840178138988472e-16
# likelihood chi2 :  3.956574625856077e-16
# loglikelihood normal :  -34.7820999319908
# loglikelihood chi2 :  -35.465982830431756
# theta= [np.float64(0.020202020202020204), np.float64(-0.050505050505050386)]
# likelihood normal :  8.34901858980155e-16
# likelihood chi2 :  7.851629174723647e-16
# loglikelihood normal :  -34.71921749010515
# loglikelihood chi2 :  -34.78064043946213
# theta= [np.float64(0.020202020202020204), np.float64(-0.030303030303030276)]
# likelihood normal :  8.872759311878002e-16
# likelihood chi2 :  1.1218137302110648e-15
# loglikelihood normal :  -34.658375656320715
# loglikelihood chi2 :  -34.423829617447
# theta= [np.float64(0.020202020202020204), np.float64(-0.010101010101010055)]
# likelihood normal :  9.410132716470073e-16
# likelihood chi2 :  1.1574316296556581e-15
# loglikelihood normal :  -34.599574430637496
# loglikelihood chi2 :  -34.3925729569291
# theta= [np.float64(0.020202020202020204), np.float64(0.010101010101010166)]
# likelihood normal :  9.95970721270071e-16
# likelihood chi2 :  7.400445644731574e-16
# loglikelihood normal :  -34.542813813055496
# loglikelihood chi2 :  -34.83982126724687
# theta= [np.float64(0.020202020202020204), np.float64(0.030303030303030498)]
# likelihood normal :  1.0519889298837733e-15
# likelihood chi2 :  2.1569408956505487e-17
# loglikelihood normal :  -34.488093803574706
# loglikelihood chi2 :  -38.37525561504912
# theta= [np.float64(0.020202020202020204), np.float64(0.05050505050505061)]
# likelihood normal :  1.1088927475277672e-15
# likelihood chi2 :  4.583571263887736e-16
# loglikelihood normal :  -34.43541440219513
# loglikelihood chi2 :  -35.31888304168668
# theta= [np.float64(0.020202020202020204), np.float64(0.07070707070707072)]
# likelihood normal :  1.1664918036335446e-15
# likelihood chi2 :  4.3989244716609905e-17
# loglikelihood normal :  -34.38477560891677
# loglikelihood chi2 :  -37.66258650811333
# theta= [np.float64(0.020202020202020204), np.float64(0.09090909090909105)]
# likelihood normal :  1.2245812773676355e-15
# likelihood chi2 :  2.0348096215203165e-15
# loglikelihood normal :  -34.33617742373961
# loglikelihood chi2 :  -33.82837413247086
# theta= [np.float64(0.020202020202020204), np.float64(0.11111111111111116)]
# likelihood normal :  1.28294285980557e-15
# likelihood chi2 :  5.31591373537793e-15
# loglikelihood normal :  -34.28961984666368
# loglikelihood chi2 :  -32.86807148154689
# theta= [np.float64(0.020202020202020204), np.float64(0.1313131313131315)]
# likelihood normal :  1.3413459058335179e-15
# likelihood chi2 :  8.84912565080805e-15
# loglikelihood normal :  -34.245102877688964
# loglikelihood chi2 :  -32.35845773729041
# theta= [np.float64(0.020202020202020204), np.float64(0.1515151515151516)]
# likelihood normal :  1.3995487707963167e-15
# likelihood chi2 :  1.1174056903255985e-14
# loglikelihood normal :  -34.20262651681546
# loglikelihood chi2 :  -32.12518165141703
# theta= [np.float64(0.020202020202020204), np.float64(0.1717171717171717)]
# likelihood normal :  1.457300323972404e-15
# likelihood chi2 :  1.1222897117971765e-14
# loglikelihood normal :  -34.16219076404317
# loglikelihood chi2 :  -32.12082031798873
# theta= [np.float64(0.020202020202020204), np.float64(0.19191919191919204)]
# likelihood normal :  1.514341628010029e-15
# likelihood chi2 :  9.007242594715902e-15
# loglikelihood normal :  -34.12379561937209
# loglikelihood chi2 :  -32.34074740845204
# theta= [np.float64(0.020202020202020204), np.float64(0.21212121212121215)]
# likelihood normal :  1.5704077705599759e-15
# likelihood chi2 :  5.636646537981024e-15
# loglikelihood normal :  -34.08744108280223
# loglikelihood chi2 :  -32.80948709170111
# theta= [np.float64(0.020202020202020204), np.float64(0.2323232323232325)]
# likelihood normal :  1.6252298315440901e-15
# likelihood chi2 :  2.58763543309666e-15
# loglikelihood normal :  -34.05312715433358
# loglikelihood chi2 :  -33.58803189639556
# theta= [np.float64(0.020202020202020204), np.float64(0.2525252525252526)]
# likelihood normal :  1.678536966862877e-15
# likelihood chi2 :  7.641082065803694e-16
# loglikelihood normal :  -34.02085383396615
# loglikelihood chi2 :  -34.80782226310542
# theta= [np.float64(0.020202020202020204), np.float64(0.27272727272727293)]
# likelihood normal :  1.7300585869248664e-15
# likelihood chi2 :  1.047336344487001e-16
# loglikelihood normal :  -33.990621121699924
# loglikelihood chi2 :  -36.79511136167638
# theta= [np.float64(0.020202020202020204), np.float64(0.29292929292929304)]
# likelihood normal :  1.7795266062288254e-15
# likelihood chi2 :  1.8249753584722614e-18
# loglikelihood normal :  -33.962429017534916
# loglikelihood chi2 :  -40.844965189156504
# theta= [np.float64(0.020202020202020204), np.float64(0.31313131313131315)]
# likelihood normal :  1.826677738396767e-15
# likelihood chi2 :  4.008594846894035e-20
# loglikelihood normal :  -33.936277521471126
# loglikelihood chi2 :  -44.66326109221703
# theta= [np.float64(0.020202020202020204), np.float64(0.3333333333333335)]
# likelihood normal :  1.871255809586147e-15
# likelihood chi2 :  3.5528201031460346e-20
# loglikelihood normal :  -33.91216663350854
# loglikelihood chi2 :  -44.78396017650609
# theta= [np.float64(0.020202020202020204), np.float64(0.3535353535353536)]
# likelihood normal :  1.9130140621423864e-15
# likelihood chi2 :  1.0080182498851196e-16
# loglikelihood normal :  -33.89009635364719
# loglikelihood chi2 :  -36.83337521337469
# theta= [np.float64(0.020202020202020204), np.float64(0.3737373737373739)]
# likelihood normal :  1.9517174197196966e-15
# likelihood chi2 :  5.200123647239922e-16
# loglikelihood normal :  -33.87006668188704
# loglikelihood chi2 :  -35.19267908428468
# theta= [np.float64(0.020202020202020204), np.float64(0.39393939393939403)]
# likelihood normal :  1.9871446849227608e-15
# likelihood chi2 :  9.519010525185587e-16
# loglikelihood normal :  -33.852077618228094
# loglikelihood chi2 :  -34.588070580933305
# theta= [np.float64(0.020202020202020204), np.float64(0.41414141414141437)]
# likelihood normal :  2.019090640819045e-15
# likelihood chi2 :  2.6009177850207164e-16
# loglikelihood normal :  -33.836129162670375
# loglikelihood chi2 :  -35.885497110926366
# theta= [np.float64(0.020202020202020204), np.float64(0.4343434343434345)]
# likelihood normal :  2.047368028446957e-15
# likelihood chi2 :  1.859992154098124e-15
# loglikelihood normal :  -33.82222131521387
# loglikelihood chi2 :  -33.91820412542128
# theta= [np.float64(0.020202020202020204), np.float64(0.4545454545454546)]
# likelihood normal :  2.0718093736943474e-15
# likelihood chi2 :  2.632599240971415e-15
# loglikelihood normal :  -33.810354075858584
# loglikelihood chi2 :  -33.57080473222055
# theta= [np.float64(0.020202020202020204), np.float64(0.4747474747474749)]
# likelihood normal :  2.092268638631325e-15
# likelihood chi2 :  9.296028375040536e-16
# loglikelihood normal :  -33.8005274446045
# loglikelihood chi2 :  -34.61177423540735
# theta= [np.float64(0.020202020202020204), np.float64(0.49494949494949503)]
# likelihood normal :  2.1086226745267894e-15
# likelihood chi2 :  2.7017954133856946e-15
# loglikelihood normal :  -33.79274142145164
# loglikelihood chi2 :  -33.54485987497298
# theta= [np.float64(0.020202020202020204), np.float64(0.5151515151515154)]
# likelihood normal :  2.120772456327085e-15
# likelihood chi2 :  5.746108773525149e-15
# loglikelihood normal :  -33.78699600639999
# loglikelihood chi2 :  -32.79025350422905
# theta= [np.float64(0.020202020202020204), np.float64(0.5353535353535355)]
# likelihood normal :  2.128644081285448e-15
# likelihood chi2 :  4.770028826848468e-14
# loglikelihood normal :  -33.78329119944955
# loglikelihood chi2 :  -30.67383895367019
# theta= [np.float64(0.020202020202020204), np.float64(0.5555555555555556)]
# likelihood normal :  2.1321895176532147e-15
# likelihood chi2 :  5.450620932519123e-13
# loglikelihood normal :  -33.781627000600324
# loglikelihood chi2 :  -28.23787667416495
# theta= [np.float64(0.020202020202020204), np.float64(0.5757575757575759)]
# likelihood normal :  2.1313870928213084e-15
# likelihood chi2 :  2.541036589946082e-12
# loglikelihood normal :  -33.78200340985232
# loglikelihood chi2 :  -26.69844901187284
# theta= [np.float64(0.020202020202020204), np.float64(0.595959595959596)]
# likelihood normal :  2.1262417139714746e-15
# likelihood chi2 :  8.020834558953108e-12
# loglikelihood normal :  -33.784420427205525
# loglikelihood chi2 :  -25.54897863974412
# theta= [np.float64(0.020202020202020204), np.float64(0.6161616161616164)]
# likelihood normal :  2.116784818094289e-15
# likelihood chi2 :  1.949397504210715e-11
# loglikelihood normal :  -33.788878052659946
# loglikelihood chi2 :  -24.66091567030022
# theta= [np.float64(0.020202020202020204), np.float64(0.6363636363636365)]
# likelihood normal :  2.1030740520862177e-15
# likelihood chi2 :  3.813734267256033e-11
# loglikelihood normal :  -33.79537628621558
# loglikelihood chi2 :  -23.98982719116309
# theta= [np.float64(0.020202020202020204), np.float64(0.6565656565656568)]
# likelihood normal :  2.085192687480085e-15
# likelihood chi2 :  5.985611531279633e-11
# loglikelihood normal :  -33.80391512787243
# loglikelihood chi2 :  -23.539077511821063
# theta= [np.float64(0.020202020202020204), np.float64(0.6767676767676769)]
# likelihood normal :  2.063248778122127e-15
# likelihood chi2 :  6.9400308769849e-11
# loglikelihood normal :  -33.814494577630484
# loglikelihood chi2 :  -23.39112979929242
# theta= [np.float64(0.020202020202020204), np.float64(0.696969696969697)]
# likelihood normal :  2.0373740727159916e-15
# likelihood chi2 :  3.4009350284987386e-11
# loglikelihood normal :  -33.827114635489764
# loglikelihood chi2 :  -24.104385620738277
# theta= [np.float64(0.020202020202020204), np.float64(0.7171717171717173)]
# likelihood normal :  2.007722697544272e-15
# likelihood chi2 :  1.0051278014214715e-10
# loglikelihood normal :  -33.84177530145026
# loglikelihood chi2 :  -23.020736230920768
# theta= [np.float64(0.020202020202020204), np.float64(0.7373737373737375)]
# likelihood normal :  1.9744696277917263e-15
# likelihood chi2 :  4.076727230891203e-10
# loglikelihood normal :  -33.858476575511965
# loglikelihood chi2 :  -21.62055641270965
# theta= [np.float64(0.020202020202020204), np.float64(0.7575757575757578)]
# likelihood normal :  1.9378089686766152e-15
# likelihood chi2 :  9.69285575655286e-10
# loglikelihood normal :  -33.87721845767488
# loglikelihood chi2 :  -20.75446183573819
# theta= [np.float64(0.020202020202020204), np.float64(0.7777777777777779)]
# likelihood normal :  1.8979520700011013e-15
# likelihood chi2 :  1.8553528998928068e-09
# loglikelihood normal :  -33.89800094793902
# loglikelihood chi2 :  -20.10519091645101
# theta= [np.float64(0.020202020202020204), np.float64(0.7979797979797982)]
# likelihood normal :  1.8551254997196805e-15
# likelihood chi2 :  3.0983711192777046e-09
# loglikelihood normal :  -33.92082404630436
# loglikelihood chi2 :  -19.59238930894441
# theta= [np.float64(0.020202020202020204), np.float64(0.8181818181818183)]
# likelihood normal :  1.809568903666553e-15
# likelihood chi2 :  4.66920090782352e-09
# loglikelihood normal :  -33.94568775277092
# loglikelihood chi2 :  -19.182277891721995
# theta= [np.float64(0.020202020202020204), np.float64(0.8383838383838385)]
# likelihood normal :  1.7615327796583307e-15
# likelihood chi2 :  6.463268403856194e-09
# loglikelihood normal :  -33.9725920673387
# loglikelihood chi2 :  -18.857130702229473
# theta= [np.float64(0.020202020202020204), np.float64(0.8585858585858588)]
# likelihood normal :  1.711276194787614e-15
# likelihood chi2 :  8.304353023450057e-09
# loglikelihood normal :  -34.00153699000769
# loglikelihood chi2 :  -18.606485998968648
# theta= [np.float64(0.020202020202020204), np.float64(0.8787878787878789)]
# likelihood normal :  1.6590644748445453e-15
# likelihood chi2 :  9.968547962041403e-09
# loglikelihood normal :  -34.032522520777896
# loglikelihood chi2 :  -18.42383090429732
# theta= [np.float64(0.020202020202020204), np.float64(0.8989898989898992)]
# likelihood normal :  1.6051668944570032e-15
# likelihood chi2 :  1.1224573819983699e-08
# loglikelihood normal :  -34.065548659649316
# loglikelihood chi2 :  -18.305160371078173
# theta= [np.float64(0.020202020202020204), np.float64(0.9191919191919193)]
# likelihood normal :  1.5498543957435818e-15
# likelihood chi2 :  1.1880822948672578e-08
# loglikelihood normal :  -34.10061540662195
# loglikelihood chi2 :  -18.248340253637302
# theta= [np.float64(0.020202020202020204), np.float64(0.9393939393939394)]
# likelihood normal :  1.4933973620537377e-15
# likelihood chi2 :  1.182659914784212e-08
# loglikelihood normal :  -34.1377227616958
# loglikelihood chi2 :  -18.252914677221952
# theta= [np.float64(0.020202020202020204), np.float64(0.9595959595959598)]
# likelihood normal :  1.4360634717609082e-15
# likelihood chi2 :  1.105622366930162e-08
# loglikelihood normal :  -34.17687072487086
# loglikelihood chi2 :  -18.320272339544907
# theta= [np.float64(0.020202020202020204), np.float64(0.9797979797979799)]
# likelihood normal :  1.3781156551183128e-15
# likelihood chi2 :  9.669630754892517e-09
# loglikelihood normal :  -34.21805929614713
# loglikelihood chi2 :  -18.45427571281289
# theta= [np.float64(0.020202020202020204), np.float64(1.0)]
# likelihood normal :  1.3198101749302584e-15
# likelihood chi2 :  7.849968929702798e-09
# loglikelihood normal :  -34.26128847552462
# loglikelihood chi2 :  -18.66275626315957
# theta= [np.float64(0.04040404040404041), np.float64(-1.0)]
# likelihood normal :  5.22122582630564e-18
# likelihood chi2 :  1.363923593040021e-26
# loglikelihood normal :  -39.79379946694154
# loglikelihood chi2 :  -59.556846876825745
# theta= [np.float64(0.04040404040404041), np.float64(-0.9797979797979798)]
# likelihood normal :  6.1014856564524056e-18
# likelihood chi2 :  4.737029082068764e-26
# loglikelihood normal :  -39.637999382129
# loglikelihood chi2 :  -58.31180225457921
# theta= [np.float64(0.04040404040404041), np.float64(-0.9595959595959596)]
# likelihood normal :  7.115615736922223e-18
# likelihood chi2 :  1.6028611095192603e-25
# loglikelihood normal :  -39.48423990541769
# loglikelihood chi2 :  -57.09283709907033
# theta= [np.float64(0.04040404040404041), np.float64(-0.9393939393939394)]
# likelihood normal :  8.281388413130754e-18
# likelihood chi2 :  5.28273872867474e-25
# ...
# loglikelihood chi2 :  -29.924687097106432
# theta= [np.float64(2.0), np.float64(-0.3535353535353535)]
# likelihood normal :  4.4477646527440024e-15
# likelihood chi2 :  9.621281060963962e-13
# loglikelihood normal :  -33.04637475016619
# loglikelihood chi2 :  -27.669628786690467
# theta= [np.float64(2.0), np.float64(-0.33333333333333326)]
# likelihood normal :  4.440292650775217e-15
# likelihood chi2 :  3.5035725749948077e-13
# loglikelihood normal :  -33.048056108301914
# loglikelihood chi2 :  -28.67982302531089
# theta= [np.float64(2.0), np.float64(-0.31313131313131304)]
# likelihood normal :  4.4237967490846386e-15
# likelihood chi2 :  4.1352152659702945e-13
# loglikelihood normal :  -33.05177807453886
# loglikelihood chi2 :  -28.514066822317027
# theta= [np.float64(2.0), np.float64(-0.2929292929292928)]
# likelihood normal :  4.3983776016661065e-15
# likelihood chi2 :  8.803433886327274e-12
# loglikelihood normal :  -33.057540648877016
# loglikelihood chi2 :  -25.455879256202834
# theta= [np.float64(2.0), np.float64(-0.2727272727272727)]
# likelihood normal :  4.364189819028972e-15
# likelihood chi2 :  3.299758709372464e-11
# loglikelihood normal :  -33.06534383131639
# loglikelihood chi2 :  -24.134586675507332
# theta= [np.float64(2.0), np.float64(-0.2525252525252525)]
# likelihood normal :  4.321440401926686e-15
# likelihood chi2 :  6.734310546823621e-11
# loglikelihood normal :  -33.07518762185697
# loglikelihood chi2 :  -23.421220587009515
# theta= [np.float64(2.0), np.float64(-0.23232323232323226)]
# likelihood normal :  4.2703866539267565e-15
# likelihood chi2 :  8.511600691172803e-11
# loglikelihood normal :  -33.087072020498766
# loglikelihood chi2 :  -23.187006002716974
# theta= [np.float64(2.0), np.float64(-0.21212121212121204)]
# likelihood normal :  4.211333602271218e-15
# likelihood chi2 :  5.5755728433855966e-11
# loglikelihood normal :  -33.10099702724178
# loglikelihood chi2 :  -23.61004095869017
# theta= [np.float64(2.0), np.float64(-0.19191919191919182)]
# likelihood normal :  4.144630963193082e-15
# likelihood chi2 :  9.849463847740823e-13
# loglikelihood normal :  -33.11696264208601
# loglikelihood chi2 :  -27.646189186921497
# theta= [np.float64(2.0), np.float64(-0.1717171717171716)]
# likelihood normal :  4.070669693919661e-15
# likelihood chi2 :  5.985635084586684e-11
# loglikelihood normal :  -33.13496886503145
# loglikelihood chi2 :  -23.539073576841226
# theta= [np.float64(2.0), np.float64(-0.1515151515151515)]
# likelihood normal :  3.989878178903659e-15
# likelihood chi2 :  5.541175456339632e-10
# loglikelihood normal :  -33.15501569607811
# loglikelihood chi2 :  -21.31364427545287
# theta= [np.float64(2.0), np.float64(-0.13131313131313127)]
# likelihood normal :  3.902718102291416e-15
# likelihood chi2 :  1.9213253074665997e-09
# loglikelihood normal :  -33.17710313522597
# loglikelihood chi2 :  -20.070250624724036
# theta= [np.float64(2.0), np.float64(-0.11111111111111105)]
# likelihood normal :  3.809680062195482e-15
# likelihood chi2 :  4.549221816396655e-09
# loglikelihood normal :  -33.20123118247506
# loglikelihood chi2 :  -19.208309647974115
# theta= [np.float64(2.0), np.float64(-0.09090909090909083)]
# likelihood normal :  3.7112789849367026e-15
# likelihood chi2 :  8.50280702837507e-09
# loglikelihood normal :  -33.22739983782535
# loglikelihood chi2 :  -18.582869489334552
# theta= [np.float64(2.0), np.float64(-0.07070707070707061)]
# likelihood normal :  3.6080493990300175e-15
# likelihood chi2 :  1.3267234458178472e-08
# loglikelihood normal :  -33.25560910127687
# loglikelihood chi2 :  -18.13796841588479
# theta= [np.float64(2.0), np.float64(-0.050505050505050386)]
# likelihood normal :  3.5005406293000163e-15
# likelihood chi2 :  1.765120803234969e-08
# loglikelihood normal :  -33.28585897282959
# loglikelihood chi2 :  -17.852461612150083
# theta= [np.float64(2.0), np.float64(-0.030303030303030276)]
# likelihood normal :  3.389311971137995e-15
# likelihood chi2 :  1.996096711943143e-08
# loglikelihood normal :  -33.31814945248354
# loglikelihood chi2 :  -17.72948711435957
# theta= [np.float64(2.0), np.float64(-0.010101010101010055)]
# likelihood normal :  3.2749279035837357e-15
# likelihood chi2 :  1.844804764785123e-08
# loglikelihood normal :  -33.352480540238695
# loglikelihood chi2 :  -17.8083072906037
# theta= [np.float64(2.0), np.float64(0.010101010101010166)]
# likelihood normal :  3.157953397681566e-15
# likelihood chi2 :  1.1902622206942545e-08
# loglikelihood normal :  -33.38885223609506
# loglikelihood chi2 :  -18.246507107578616
# theta= [np.float64(2.0), np.float64(0.030303030303030498)]
# likelihood normal :  3.038949373487867e-15
# likelihood chi2 :  1.7451493700091574e-10
# loglikelihood normal :  -33.42726454005264
# loglikelihood chi2 :  -22.46901077909033
# theta= [np.float64(2.0), np.float64(0.05050505050505061)]
# likelihood normal :  2.918468355277458e-15
# likelihood chi2 :  1.559374702017671e-08
# loglikelihood normal :  -33.46771745211144
# loglikelihood chi2 :  -17.976395835085512
# theta= [np.float64(2.0), np.float64(0.07070707070707072)]
# likelihood normal :  2.7970503700026323e-15
# likelihood chi2 :  3.313760410250437e-08
# loglikelihood normal :  -33.51021097227145
# loglikelihood chi2 :  -17.22259712380457
# theta= [np.float64(2.0), np.float64(0.09090909090909105)]
# likelihood normal :  2.6752191290051e-15
# likelihood chi2 :  4.960631091246394e-08
# loglikelihood normal :  -33.55474510053268
# loglikelihood chi2 :  -16.819147775170972
# theta= [np.float64(2.0), np.float64(0.11111111111111116)]
# likelihood normal :  2.5534785274789825e-15
# likelihood chi2 :  6.228616369410359e-08
# loglikelihood normal :  -33.60131983689512
# loglikelihood chi2 :  -16.591526527406412
# theta= [np.float64(2.0), np.float64(0.1313131313131315)]
# likelihood normal :  2.43230949034834e-15
# likelihood chi2 :  6.926928379303964e-08
# loglikelihood normal :  -33.64993518135877
# loglikelihood chi2 :  -16.48526426431803
# theta= [np.float64(2.0), np.float64(0.1515151515151516)]
# likelihood normal :  2.3121671871736214e-15
# likelihood chi2 :  6.985965845752931e-08
# loglikelihood normal :  -33.70059113392364
# loglikelihood chi2 :  -16.476777486535738
# theta= [np.float64(2.0), np.float64(0.1717171717171717)]
# likelihood normal :  2.1934786325555754e-15
# likelihood chi2 :  6.461669637990799e-08
# loglikelihood normal :  -33.75328769458972
# loglikelihood chi2 :  -16.55479300165903
# theta= [np.float64(2.0), np.float64(0.19191919191919204)]
# likelihood normal :  2.0766406823764467e-15
# likelihood chi2 :  5.506829785510402e-08
# loglikelihood normal :  -33.80802486335702
# loglikelihood chi2 :  -16.714691642900313
# theta= [np.float64(2.0), np.float64(0.21212121212121215)]
# likelihood normal :  1.962018430215939e-15
# likelihood chi2 :  4.3226396943663584e-08
# loglikelihood normal :  -33.86480264022553
# loglikelihood chi2 :  -16.956814487942914
# theta= [np.float64(2.0), np.float64(0.2323232323232325)]
# likelihood normal :  1.849944002504127e-15
# likelihood chi2 :  3.107568387490072e-08
# loglikelihood normal :  -33.92362102519525
# loglikelihood chi2 :  -17.286840192554443
# theta= [np.float64(2.0), np.float64(0.2525252525252526)]
# likelihood normal :  1.7407157455173022e-15
# likelihood chi2 :  2.017944220410597e-08
# loglikelihood normal :  -33.98448001826619
# loglikelihood chi2 :  -17.718601463428445
# theta= [np.float64(2.0), np.float64(0.27272727272727293)]
# likelihood normal :  1.6345977922656931e-15
# likelihood chi2 :  1.1478838839481752e-08
# loglikelihood normal :  -34.047379619438345
# loglikelihood chi2 :  -18.28276059755724
# theta= [np.float64(2.0), np.float64(0.29292929292929304)]
# likelihood normal :  1.5318199927331336e-15
# likelihood chi2 :  5.286914628321434e-09
# loglikelihood normal :  -34.11231982871171
# loglikelihood chi2 :  -19.058031007294353
# theta= [np.float64(2.0), np.float64(0.31313131313131315)]
# likelihood normal :  1.4325781868629308e-15
# likelihood chi2 :  1.4233440372972241e-09
# loglikelihood normal :  -34.17930064608629
# loglikelihood chi2 :  -20.370256778052926
# theta= [np.float64(2.0), np.float64(0.3333333333333335)]
# likelihood normal :  1.3370347961836803e-15
# likelihood chi2 :  5.866510186204952e-10
# loglikelihood normal :  -34.24832207156209
# loglikelihood chi2 :  -21.25659098972616
# theta= [np.float64(2.0), np.float64(0.3535353535353536)]
# likelihood normal :  1.2453197070615832e-15
# likelihood chi2 :  1.3186295876115024e-09
# loglikelihood normal :  -34.31938410513909
# loglikelihood chi2 :  -20.44667283084532
# theta= [np.float64(2.0), np.float64(0.3737373737373739)]
# likelihood normal :  1.1575314162670747e-15
# likelihood chi2 :  1.30482071915178e-09
# loglikelihood normal :  -34.392486746817326
# loglikelihood chi2 :  -20.457200185569565
# theta= [np.float64(2.0), np.float64(0.39393939393939403)]
# likelihood normal :  1.0737384078549936e-15
# likelihood chi2 :  9.54943393178663e-10
# loglikelihood normal :  -34.46762999659676
# loglikelihood chi2 :  -20.76936905136307
# theta= [np.float64(2.0), np.float64(0.41414141414141437)]
# likelihood normal :  9.939807292690858e-16
# likelihood chi2 :  5.347930127377563e-10
# loglikelihood normal :  -34.54481385447742
# loglikelihood chi2 :  -21.349141335973556
# theta= [np.float64(2.0), np.float64(0.4343434343434345)]
# likelihood normal :  9.182717340719889e-16
# likelihood chi2 :  1.8366002974135685e-10
# loglikelihood normal :  -34.624038320459285
# loglikelihood chi2 :  -22.41793473180614
# theta= [np.float64(2.0), np.float64(0.4545454545454546)]
# likelihood normal :  8.465999587397982e-16
# likelihood chi2 :  5.0154208938464156e-11
# loglikelihood normal :  -34.70530339454236
# loglikelihood chi2 :  -23.715918678053956
# theta= [np.float64(2.0), np.float64(0.4747474747474749)]
# likelihood normal :  7.789311015061682e-16
# likelihood chi2 :  1.7190196071815585e-10
# loglikelihood normal :  -34.78860907672666
# loglikelihood chi2 :  -22.484096797449144
# theta= [np.float64(2.0), np.float64(0.49494949494949503)]
# likelihood normal :  7.152100722477967e-16
# likelihood chi2 :  2.1035257851898767e-10
# loglikelihood normal :  -34.87395536701216
# loglikelihood chi2 :  -22.282236047735687
# theta= [np.float64(2.0), np.float64(0.5151515151515154)]
# likelihood normal :  6.553630838187448e-16
# likelihood chi2 :  1.9829421725245678e-10
# loglikelihood normal :  -34.96134226539889
# loglikelihood chi2 :  -22.341269242439417
# theta= [np.float64(2.0), np.float64(0.5353535353535355)]
# likelihood normal :  5.992997570089858e-16
# likelihood chi2 :  1.6263654583527233e-10
# loglikelihood normal :  -35.05076977188682
# loglikelihood chi2 :  -22.53950318493487
# theta= [np.float64(2.0), np.float64(0.5555555555555556)]
# likelihood normal :  5.469152133639621e-16
# likelihood chi2 :  1.2133385940778745e-10
# loglikelihood normal :  -35.142237886475975
# loglikelihood chi2 :  -22.832475201190846
# theta= [np.float64(2.0), np.float64(0.5757575757575759)]
# likelihood normal :  4.980921323969285e-16
# likelihood chi2 :  8.414711561936358e-11
# loglikelihood normal :  -35.23574660916634
# loglikelihood chi2 :  -23.198454472535595
# theta= [np.float64(2.0), np.float64(0.595959595959596)]
# likelihood normal :  4.527027521948427e-16
# likelihood chi2 :  5.492902298749065e-11
# loglikelihood normal :  -35.33129593995792
# loglikelihood chi2 :  -23.624979255233374
# theta= [np.float64(2.0), np.float64(0.6161616161616164)]
# likelihood normal :  4.106107950036592e-16
# likelihood chi2 :  3.40179464181875e-11
# loglikelihood normal :  -35.428885878850714
# loglikelihood chi2 :  -24.104132894739678
# theta= [np.float64(2.0), np.float64(0.6363636363636365)]
# likelihood normal :  3.7167330202473687e-16
# likelihood chi2 :  2.0095710011299955e-11
# loglikelihood normal :  -35.52851642584472
# loglikelihood chi2 :  -24.63051475591706
# theta= [np.float64(2.0), np.float64(0.6565656565656568)]
# likelihood normal :  3.3574236430908246e-16
# likelihood chi2 :  1.1367724790810668e-11
# loglikelihood normal :  -35.630187580939946
# loglikelihood chi2 :  -25.200242934539155
# theta= [np.float64(2.0), np.float64(0.6767676767676769)]
# likelihood normal :  3.026667392531817e-16
# likelihood chi2 :  6.1756060883937924e-12
# loglikelihood normal :  -35.733899344136375
# loglikelihood chi2 :  -25.81041408626449
# theta= [np.float64(2.0), np.float64(0.696969696969697)]
# likelihood normal :  2.7229334473687473e-16
# likelihood chi2 :  3.22919408715915e-12
# loglikelihood normal :  -35.83965171543403
# loglikelihood chi2 :  -26.4587885184459
# theta= [np.float64(2.0), np.float64(0.7171717171717173)]
# likelihood normal :  2.44468625363647e-16
# likelihood chi2 :  1.6281190545959972e-12
# loglikelihood normal :  -35.947444694832896
# loglikelihood chi2 :  -27.143595721663306
# theta= [np.float64(2.0), np.float64(0.7373737373737375)]
# likelihood normal :  2.1903978753562047e-16
# likelihood chi2 :  7.926389246082231e-13
# loglikelihood normal :  -36.05727828233297
# loglikelihood chi2 :  -27.86340860533217
# theta= [np.float64(2.0), np.float64(0.7575757575757578)]
# likelihood normal :  1.9585590219451242e-16
# likelihood chi2 :  3.730518204360906e-13
# loglikelihood normal :  -36.16915247793427
# loglikelihood chi2 :  -28.617059056133492
# theta= [np.float64(2.0), np.float64(0.7777777777777779)]
# likelihood normal :  1.7476887596647605e-16
# likelihood chi2 :  1.6989777216885754e-13
# loglikelihood normal :  -36.28306728163677
# loglikelihood chi2 :  -29.40357947892114
# theta= [np.float64(2.0), np.float64(0.7979797979797982)]
# likelihood normal :  1.5563429314940005e-16
# likelihood chi2 :  7.493455133526873e-14
# loglikelihood normal :  -36.3990226934405
# loglikelihood chi2 :  -30.222161311217132
# theta= [np.float64(2.0), np.float64(0.8181818181818183)]
# likelihood normal :  1.3831213246767833e-16
# likelihood chi2 :  3.2029308871399474e-14
# loglikelihood normal :  -36.51701871334543
# loglikelihood chi2 :  -31.07212500906224
# theta= [np.float64(2.0), np.float64(0.8383838383838385)]
# likelihood normal :  1.2266736378827253e-16
# likelihood chi2 :  1.3274944174766586e-14
# loglikelihood normal :  -36.637055341351584
# loglikelihood chi2 :  -31.95289803308218
# theta= [np.float64(2.0), np.float64(0.8585858585858588)]
# likelihood normal :  1.0857043104439667e-16
# likelihood chi2 :  5.337609038203119e-15
# loglikelihood normal :  -36.75913257745894
# loglikelihood chi2 :  -32.86399858786144
# theta= [np.float64(2.0), np.float64(0.8787878787878789)]
# likelihood normal :  9.589762845453747e-17
# likelihood chi2 :  2.082882520178099e-15
# loglikelihood normal :  -36.883250421667526
# loglikelihood chi2 :  -33.80502363356075
# theta= [np.float64(2.0), np.float64(0.8989898989898992)]
# likelihood normal :  8.453137776355699e-17
# likelihood chi2 :  7.89098762899863e-16
# loglikelihood normal :  -37.009408873977314
# loglikelihood chi2 :  -34.775640186102635
# theta= [np.float64(2.0), np.float64(0.9191919191919193)]
# likelihood normal :  7.436041468094388e-17
# likelihood chi2 :  2.903108991213875e-16
# loglikelihood normal :  -37.13760793438832
# loglikelihood chi2 :  -35.77557925922877
# theta= [np.float64(2.0), np.float64(0.9393939393939394)]
# likelihood normal :  6.527989296284999e-17
# likelihood chi2 :  1.0374123060446163e-16
# loglikelihood normal :  -37.26784760290054
# loglikelihood chi2 :  -36.80463204264874
# theta= [np.float64(2.0), np.float64(0.9595959595959598)]
# likelihood normal :  5.719141469516547e-17
# likelihood chi2 :  3.6013129413793975e-17
# loglikelihood normal :  -37.400127879513974
# loglikelihood chi2 :  -37.86264809598704
# theta= [np.float64(2.0), np.float64(0.9797979797979799)]
# likelihood normal :  5.0002995301517376e-17
# likelihood chi2 :  1.2145954817689124e-17
# loglikelihood normal :  -37.53444876422863
# loglikelihood chi2 :  -38.94953549635774
# theta= [np.float64(2.0), np.float64(1.0)]
# likelihood normal :  4.362897164048972e-17
# likelihood chi2 :  3.979947560468584e-18
# loglikelihood normal :  -37.67081025704448
# loglikelihood chi2 :  -40.06526303044493
#
# Maximum likelihood (normal): 4.4477646527440024e-15 for theta = [np.float64(2.0), np.float64(-0.3535353535353535)]
# Maximum likelihood (chi2): 4.594841171534697e-07 for theta = [np.float64(1.272727272727273), np.float64(0.4545454545454546)]
#
# Maximum log-likelihood (normal): -33.04637475016619 for theta = [np.float64(2.0), np.float64(-0.3535353535353535)]
# Maximum log-likelihood (chi2): -14.593161461246503 for theta = [np.float64(1.272727272727273), np.float64(0.4545454545454546)]

# %% [markdown]
# ### <span style="color:blue">QUESTION 3.3 :</span>
#
# Codez une fonction de descente de gradient pour apprendre les parametres optimaux du modele (a et b) avec les deux types de bruit consideres mais leurs parametres fixes aux valeurs par defaut.
#
# Remarque: on **maximisera** idéalement la log-vraisemblance plutôt que la vraisemblance, ce qui est numeriquement plus efficace et conduit au même résultat.

# %%
def MinusLikelihood_normal(X,Y,theta,sigma=2.):
    return -likelihood_normal(X,Y,theta,sigma=sigma)

def MinusLikelihood_chi2(X,Y,theta,dof=3,sc=0.4):
    return -likelihood_chi2(X,Y,theta,dof=dof,sc=sc)

#3.1: fonctions pour la descente de gradient

def Grad_function(f,X,Y,theta_loc,epsilon=1e-5):
  d_a = (f(X, Y, [theta_loc[0]+epsilon, theta_loc[1]]) - f(X, Y, [theta_loc[0]-epsilon, theta_loc[1]]))/(2*epsilon)
  d_b = (f(X, Y, [theta_loc[0], theta_loc[1]+epsilon]) - f(X, Y, [theta_loc[0], theta_loc[1]-epsilon]))/(2*epsilon)
  ApproxGrad = np.array([d_a, d_b])
  return ApproxGrad

Grad_function(MinusLikelihood_normal,X,Y,[1.2,-0.3],epsilon=1e-5)
#descente de gradient avec alpha defini a la main

def grad_descent(funct,X,Y,theta_init,convspeedfactor=0.1,nbIterations=100):
    theta=theta_init
    for i in range(nbIterations):
        grad=Grad_function(funct,X,Y,theta,epsilon=1e-5)
        theta=theta-convspeedfactor*grad
    return theta

grad_descent(MinusLikelihood_chi2,X,Y,[1,0],convspeedfactor=0.1,nbIterations=1000)
# Out:
# array([ 9.99999999e-01, -3.03356933e-09])

# %% [markdown]
# l'optimisation marche aussi, meme si il faut faire tres attention au choix du theta_init (la densite du chi2 est nulle pour les erreurs negatives)... par contre :
#   -> la vraisemblance est de 10e-7 au lieu de 10e-15
#   -> le modele lineaire colle mieux a la majorite des donnees et est moins sensible aux donnees visiblement aberrantes
#
#
# On peut alors plus faire confiance a la pente calculee avec le bruit de type chi2 que le bruit gaussien, MAIS en etant clair sur le fait qu'on aura une tendance loin d'etre negligeable de s'eloigner regulierement du modele lineaire de maniere non-symetrique par rapport au modele.

# %%
"""
#Remarque : Generation de donnees dans cet exercice :

import numpy as np
import matplotlib.pyplot as plt
n = 20
X = np.random.uniform(size=n)
y = 1.2*X[:] + np.random.chisquare(1.,size=n)*0.4-0.5

plt.plot(X[], y, 'r.')
plt.show()

MyData=np.concatenate((X.reshape(-1,1),y.reshape(-1,1)),axis=1)
np.savetxt('J18_E4_QuantifiedData.csv',MyData)
"""
